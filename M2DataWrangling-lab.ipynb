# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
df.duplicated().value_counts()
#---> There are 154 duplicate Rows
# Out:
# False    11398
# True       154
# dtype: int64

# %%
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
# number of Duplicates in the Respondent Column:
df["Respondent"].duplicated().value_counts()
# Out:
# False    11398
# True       154
# Name: Respondent, dtype: int64

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df.drop_duplicates(keep="first", inplace=True)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
# checking again for duplicates
df.duplicated().value_counts()      #--> no duplicate rows left in Dataset
# Out:
# False    11398
# dtype: int64

# %%
df["Respondent"].nunique()
# Out:
# 11398

# %% [markdown]
# ## Finding Missing values

# %%
len(df)
# Out:
# 11398

# %% [markdown]
# Find the missing values for all columns.

# %%
# Loop, that prints the number of Missing Values for all columns:
for i in df.columns:
    #print(df[i].isna().value_counts())
    if df[i].isna().value_counts()[0]== 11398:
        print(f"Column {i} has no missing values.")
    elif df[i].isna().value_counts()[0] != 11398:
        print(f"Column {i} has {df[i].isna().value_counts()[1]} missing values.")
# Out:
# Column Respondent has no missing values.
# Column MainBranch has no missing values.
# Column Hobbyist has no missing values.
# Column OpenSourcer has no missing values.
# Column OpenSource has 81 missing values.
# Column Employment has no missing values.
# Column Country has no missing values.
# Column Student has 51 missing values.
# Column EdLevel has 112 missing values.
# Column UndergradMajor has 737 missing values.
# Column EduOther has 164 missing values.
# Column OrgSize has 96 missing values.
# Column DevType has 65 missing values.
# Column YearsCode has 9 missing values.
# Column Age1stCode has 13 missing values.
# Column YearsCodePro has 16 missing values.
# Column CareerSat has no missing values.
# Column JobSat has 1 missing values.
# Column MgrIdiot has 493 missing values.
# Column MgrMoney has 497 missing values.
# Column MgrWant has 493 missing values.
# Column JobSeek has no missing values.
# Column LastHireDate has no missing values.
# ...

# %%
# Usind pd.isna() or pd.isnull()
# creating a function, that gives out the number of missing Values od each Column of a DataFrame:
def mising_values_column(df, column):
        """ Input: DataFrame and column name as a string
            Outpur: Print Statement with column name and the corresponding number of missing values"""
        if df[column].isna().value_counts()[0]== len(df):
            return(f"Column: {column} Number of missing values: 0")
        elif df[column].isna().value_counts()[0] != len(df):
            return(f"Column: {column}, Number of missing values: {df[column].isna().value_counts()[1]}")

# %%
# Calling the Function:
mising_values_column(df,"Country")
# Out:
# 'Column: Country Number of missing values: 0'

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
# Calling the Function:
mising_values_column(df,"WorkLoc")  #--> 32 missing Values
# Out:
# 'Column: WorkLoc, Number of missing values: 32'

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df["WorkLoc"].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# What is the majority category under the column Employment?

# %%
df["Employment"].value_counts()
# Out:
# Employed full-time    10968
# Employed part-time      430
# Name: Employment, dtype: int64

# %% [markdown]
# Under the column " UndergradMajor", which category has the minimum number of rows?

# %%
df["UndergradMajor"].value_counts()
# Out:
# Computer science, computer engineering, or software engineering          6953
# Information systems, information technology, or system administration     794
# Another engineering discipline (ex. civil, electrical, mechanical)        759
# Web development or web design                                             410
# A natural science (ex. biology, chemistry, physics)                       403
# Mathematics or statistics                                                 372
# A business discipline (ex. accounting, finance, marketing)                244
# A social science (ex. anthropology, psychology, political science)        210
# A humanities discipline (ex. literature, history, philosophy)             207
# Fine arts or performing arts (ex. graphic design, music, studio art)      161
# I never declared a major                                                  124
# A health science (ex. nursing, pharmacy, radiology)                        24
# Name: UndergradMajor, dtype: int64

# %% [markdown]
# The column ‘ConvertedComp’ contains the annual compensation of the survey respondents. What is the best approach to impute the missing values in this column?

# %%
df["ConvertedComp"].value_counts()
# Out:
# 2000000.0    138
# 1000000.0    105
# 100000.0      99
# 150000.0      92
# 120000.0      86
#             ...
# 79183.0        1
# 20475.0        1
# 288732.0       1
# 22056.0        1
# 19880.0        1
# Name: ConvertedComp, Length: 3515, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
# most frequent WorkLoc is Office: 6806

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df["WorkLoc"].fillna("Office",inplace=True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
df["WorkLoc"].value_counts()
# no missing Values left in the WorkLoc column:
# Out:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df["CompFreq"].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here
# creating dictionairy for the Mapinf process:
categories = {"Yearly":1, "Monthly":12, "Weekly":52}
df["NormalizedAnnualCompensation"] = df["CompFreq"].map(categories) * df["CompTotal"]
df["NormalizedAnnualCompensation"]
# Out:
# 0         61000.0
# 1        138000.0
# 2         90000.0
# 3        348000.0
# 4         90000.0
#            ...
# 11547    130000.0
# 11548     74400.0
# 11549    105000.0
# 11550     80000.0
# 11551         NaN
# Name: NormalizedAnnualCompensation, Length: 11398, dtype: float64

# %%
# lets Take a Look:
df[["CompFreq","CompTotal" ,"NormalizedAnnualCompensation"]]
# Out:
#       CompFreq  CompTotal  NormalizedAnnualCompensation
# 0       Yearly    61000.0                       61000.0
# 1       Yearly   138000.0                      138000.0
# 2       Yearly    90000.0                       90000.0
# 3      Monthly    29000.0                      348000.0
# 4       Yearly    90000.0                       90000.0
# ...        ...        ...                           ...
# 11547   Yearly   130000.0                      130000.0
# 11548   Yearly    74400.0                       74400.0
# 11549   Yearly   105000.0                      105000.0
# 11550   Yearly    80000.0                       80000.0
# 11551      NaN        NaN                           NaN
#
# [11398 rows x 3 columns]

# %% [markdown]
# What is the median NormalizedAnnualCompensation?

# %%
df["NormalizedAnnualCompensation"].median()
# Out:
# 100000.0

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
